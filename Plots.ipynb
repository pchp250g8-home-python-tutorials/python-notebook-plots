# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-4,4,0.1)
y = x ** 2

plt.plot(y)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-4,4,0.1)
y = x
plt.plot(y)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, -0.5, 0.1)
y = 1 / x
plt.plot(y)

x = np.arange(0.5, 10, 0.1)
y = 1 / x
plt.plot(y)
